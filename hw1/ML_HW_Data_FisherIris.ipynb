# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
Iris=pd.read_csv("ML_HW_Data_FisherIris.csv",header=None)

# %%
print(Iris.shape)# total number of rows and columns
# Out:
# (150, 5)

# %%
print(Iris.index[Iris.iloc[:, 4] < 0]) #5th column less than 0
# Out:
# Index([10, 23, 58, 89, 108, 136], dtype='int64')

# %%
Iris = Iris[Iris.iloc[:, 4] >= 0] # keep only rows having 5th column greater than 0

# %%
print(Iris.shape)
# Out:
# (144, 5)

# %%
X = Iris.iloc[:, 0:4] # first 4 columns from Iris

# %%
Y = Iris.iloc[:, 4] # 5th column from Iris

# %%
print(X.max())
# Out:
# 0    25
# 1    69
# 2    44
# 3    79
# dtype: int64

# %%
print(X.min())
# Out:
# 0     1
# 1    10
# 2    20
# 3    43
# dtype: int64

# %%
print(len(X[X.iloc[:, 2] > 36])) #number of elements in 3 rd column of X that have value greater than 36
# Out:
# 15
